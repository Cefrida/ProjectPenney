# %%
# !pip install numpy matplotlib seaborn

# %%
from src.processing import run_simulation_for_deck, load_decks_in_batches, simulate_game, compute_win_draw_percentages
from src.visualization import create_heatmap_tricks, create_heatmap_cards
from src.datagen import generate_sequences, DeckStorage, generate_and_save_decks
import main
import numpy as np

# %%
# add 1,000,000 decks seed 42

# %%
#generate_and_save_decks(42,700000)
deck_storage = DeckStorage()
seed = 42  # Replace with the seed you want to check
num_decks = deck_storage.count_decks(seed)
print(f"Total decks saved for seed {seed}: {num_decks}")
# Out:
# Total decks saved for seed 42: 1700000

# %%
main.main()
# Out:
# Processing Batches: 100%|██████████| 100/100 [1:10:51<00:00, 42.52s/batch]
# Simulation complete, results saved, and heatmaps visualized successfully.
# Heatmaps saved in the 'saved_heatmaps' folder.
